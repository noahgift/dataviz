# %% [markdown]
# <a href="https://colab.research.google.com/github/noahgift/dataviz/blob/main/dataviz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ![Oldmansea](https://user-images.githubusercontent.com/58792/131202285-754d8751-3d9b-4564-93fa-99cfbc47bd37.jpg)

# %% [markdown]
# ## Ingest

# %% [markdown]
# ingest should be 100% reproducible

# %%
import pandas as pd

#not reproducible
#df = read_csv("C:/data.txt")

# %%
df = pd.read_csv("https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv")
df.head()
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0
# 2  2020-01-23  Washington    53      1       0
# 3  2020-01-24    Illinois    17      1       0
# 4  2020-01-24  Washington    53      1       0

# %% [markdown]
# ## EDA

# %%
df.describe()
# Out:
#                fips         cases        deaths
# count  29824.000000  2.982400e+04  29824.000000
# mean      31.962010  3.061462e+05   5930.016463
# std       18.667252  5.342826e+05   9915.165373
# min        1.000000  1.000000e+00      0.000000
# 25%       17.000000  1.520500e+04    334.000000
# 50%       31.000000  1.058830e+05   1994.000000
# 75%       46.000000  3.827505e+05   7125.000000
# max       78.000000  4.381691e+06  65483.000000

# %%
import seaborn as sns
sns.scatterplot(x="cases", y="deaths", 
                hue="deaths",size="deaths", data=df)

# %% [markdown]
# ## Data Scraping

# %%
var = {
    "KeyPhrases": [
        {
            "Score": 0.8321895599365234,
            "Text": "chapter 1\n\n\nEverybody",
            "BeginOffset": 3,
            "EndOffset": 24
        },
        {
            "Score": 0.9999736547470093,
            "Text": "The whole battery",
            "BeginOffset": 36,
            "EndOffset": 53
        },
        {
            "Score": 0.9999653100967407,
            "Text": "the road",
            "BeginOffset": 76,
            "EndOffset": 84
        },
        {
            "Score": 0.9995299577713013,
            "Text": "the dark",
            "BeginOffset": 88,
            "EndOffset": 96
        },
        {
            "Score": 0.9999217987060547,
            "Text": "the Champagne",
            "BeginOffset": 115,
            "EndOffset": 128
        },
        {
            "Score": 0.9995370507240295,
            "Text": "The lieutenant",
            "BeginOffset": 130,
            "EndOffset": 144
        },
        {
            "Score": 0.9998124241828918,
            "Text": "his horse",
            "BeginOffset": 157,
            "EndOffset": 166
        },
        {
            "Score": 0.9998575448989868,
            "Text": "the fields",
            "BeginOffset": 176,
            "EndOffset": 186
        },
        {
            "Score": 0.901852011680603,
            "Text": "mon vieux",
            "BeginOffset": 230,
            "EndOffset": 239
        },
        {
            "Score": 0.9997225403785706,
            "Text": "the road",
            "BeginOffset": 276,
            "EndOffset": 284
        },
        {
            "Score": 0.9958783388137817,
            "Text": "all\nnight",
            "BeginOffset": 285,
            "EndOffset": 294
        },
        {
            "Score": 0.9981445074081421,
            "Text": "the dark",
            "BeginOffset": 298,
            "EndOffset": 306
        },
        {
            "Score": 0.999767005443573,
            "Text": "the adjutant",
            "BeginOffset": 311,
            "EndOffset": 323
        },
        {
            "Score": 0.9998540878295898,
            "Text": "my\nkitchen",
            "BeginOffset": 349,
            "EndOffset": 359
        },
        {
            "Score": 0.6949998736381531,
            "Text": "fifty kilometers",
            "BeginOffset": 441,
            "EndOffset": 457
        },
        {
            "Score": 0.9996982216835022,
            "Text": "the front",
            "BeginOffset": 463,
            "EndOffset": 472
        },
        {
            "Score": 0.9994677305221558,
            "Text": "the adjutant",
            "BeginOffset": 477,
            "EndOffset": 489
        },
        {
            "Score": 0.9997609853744507,
            "Text": "the fire",
            "BeginOffset": 504,
            "EndOffset": 512
        },
        {
            "Score": 0.9999539852142334,
            "Text": "my kitchen",
            "BeginOffset": 516,
            "EndOffset": 526
        },
        {
            "Score": 0.9994959831237793,
            "Text": "that\nroad",
            "BeginOffset": 553,
        {
            "Score": 0.999106764793396,
            "Text": "Greek cavalry",
            "BeginOffset": 2025,
            "EndOffset": 2038
        },
        {
            "Score": 0.9999712109565735,
            "Text": "the procession",
            "BeginOffset": 2052,
            "EndOffset": 2066
        },
        {
            "Score": 0.8895770907402039,
            "Text": "Women and kids",
            "BeginOffset": 2068,
            "EndOffset": 2082
        },
        {
            "Score": 0.9999451041221619,
            "Text": "the carts",
            "BeginOffset": 2091,
            "EndOffset": 2100
        },
        {
            "Score": 0.7887174487113953,
            "Text": "mattresses, mirrors,",
            "BeginOffset": 2115,
            "EndOffset": 2135
        },
        {
            "Score": 0.7344608306884766,
            "Text": "sewing machines",
            "BeginOffset": 2136,
            "EndOffset": 2151
        },
        {
            "Score": 0.9680638313293457,
            "Text": "bundles",
            "BeginOffset": 2153,
            "EndOffset": 2160
        },
        {
            "Score": 0.9998926520347595,
            "Text": "a woman",
            "BeginOffset": 2172,
            "EndOffset": 2179
        },
        {
            "Score": 0.9998267889022827,
            "Text": "a kid",
            "BeginOffset": 2187,
            "EndOffset": 2192
        },
        {
            "Score": 0.9999517202377319,
            "Text": "a young girl",
            "BeginOffset": 2198,
            "EndOffset": 2210
        },
        {
            "Score": 0.9999311566352844,
            "Text": "a\nblanket",
            "BeginOffset": 2219,
            "EndOffset": 2228
        },
        {
            "Score": 0.7066777944564819,
            "Text": "Scared",
            "BeginOffset": 2250,
            "EndOffset": 2256
        },
        {
            "Score": 0.9999763369560242,
            "Text": "the evacuation",
            "BeginOffset": 2299,
            "EndOffset": 2313
        }
    ]
}

# %%
type(var)
# Out:
# dict

# %%
var.keys()
# Out:
# dict_keys(['KeyPhrases'])

# %%
var['KeyPhrases'][0]["Text"]
# Out:
# 'chapter 1\n\n\nEverybody'

# %% [markdown]
# ## GUI Sentiment Analysis

# %% [markdown]
# ![Screen Shot 2021-08-27 at 9 32 31 PM](https://user-images.githubusercontent.com/58792/131202070-724abcbe-78bb-499e-b85a-24457a5e1a82.png)

# %% [markdown]
# ## GUI Computer Vision

# %%
labels = {
    "Labels": [
        {
            "Name": "Novel",
            "Confidence": 91.89423370361328,
            "Instances": [],
            "Parents": [
                {
                    "Name": "Book"
                }
            ]
        },
        {
            "Name": "Book",
            "Confidence": 91.89423370361328,
            "Instances": [],
            "Parents": []
        },
        {
            "Name": "Art",
            "Confidence": 74.72328186035156,
            "Instances": [],
            "Parents": []
        },
        {
            "Name": "Person",
            "Confidence": 58.091854095458984,
            "Instances": [
                {
                    "BoundingBox": {
                        "Width": 0.1540011614561081,
                        "Height": 0.12044890969991684,
                        "Left": 0.5415842533111572,
                        "Top": 0.5163255333900452
                    },
                    "Confidence": 58.091854095458984
                }
            ],
            "Parents": []
        },
        {
            "Name": "Human",
            "Confidence": 58.091854095458984,
            "Instances": [],
            "Parents": []
        }
    ],
    "LabelModelVersion": "2.0"
}

# %%
labels.keys()
# Out:
# dict_keys(['Labels', 'LabelModelVersion'])

# %%
labels['Labels'][0]['Name']
# Out:
# 'Novel'

# %% [markdown]
# ### Output of CV Labeling

# %% [markdown]
# ![Screen Shot 2021-08-27 at 9 37 57 PM](https://user-images.githubusercontent.com/58792/131202224-262441f8-ea60-4dc8-ba74-307fb93cd88c.png)

# %% [markdown]
# ## Model

# %% [markdown]
# ## Conclusion
